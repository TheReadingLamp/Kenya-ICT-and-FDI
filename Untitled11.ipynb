# %%
import pandas as pd

# Provided data
data = {
    'Year': [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018],
    'Government effectiveness (Rank)': [36.89, 31.07, 30.62, 34.93, 33.65, 35.55, 37.44, 40.87, 38.57, 37.14, 37.14, 34.29],
    'Gross National Income Per Capita (2017 PPP$)': [36.89, 31.07, 30.62, 34.93, 33.65, 35.55, 37.44, 40.87, 38.57, 37.14, 37.14, 34.29],
    'Individuals using the Internet (% of population)': [36.89, 31.07, 30.62, 34.93, 33.65, 35.55, 37.44, 40.87, 38.57, 37.14, 37.14, 34.29],
    'Total Agent Cash in Cash Out (Volume Million)': [36.89, 31.07, 30.62, 34.93, 33.65, 35.55, 37.44, 40.87, 38.57, 37.14, 37.14, 34.29],
    'Life expectancy (Years)': [57.13, 58.49, 59.38, 60.26, 61.15, 62.03, 62.92, 63.57, 64.22, 64.87, 65.53, 66.18],
    'GDP (USD)': [840.19, 915.99, 1049.12, 1093.64, 1099.32, 1289.78, 1376.83, 1489.92, 1496.65, 1562.08, 1675.99, 1845.78],
    'Mean years of Schooling (Years)': [6.16, 6.23, 6.31, 5.82, 6.05, 6.3, 6.54, 6.79, 7.03, 7.27, 7.51, 7.75],
    'Labour Force Participation Rate, Female (%)': [10.8, 10.659, 10.353, 10.177, 9.734, 9.37, 9.086, 8.695, 8.143, 7.681, 7.235, 7.13],
    'Labour Force Participation Rate, Male (%)': [49.41, 48.351, 46.413, 47.55, 47.28, 47.698, 51.621, 50.685, 48.297, 50.467, 48.994, 51.151],
    'HDI Index': [0.54, 0.55, 0.55, 0.54, 0.55, 0.56, 0.56, 0.57, 0.57, 0.59, 0.59, 0.6],
    'CO2 emission per capita (tonne)': [0.258266, 0.261128, 0.305781, 0.292963, 0.315411, 0.286003, 0.300453, 0.317061, 0.362817, 0.378633, 0.361799, 0.377112],
    'Rule of law (rank)': [17.22, 16.35, 16.59, 18.01, 19.25, 23.94, 30.05, 38.94, 36.67, 35.24, 37.14, 36.67],
    'FDI Investment Value': [729044146, 95585680.23, 116257609, 178064606.8, 1450474757, 1380173662, 1118825000, 820937598.4, 619724465, 469533310.7, 1346085345, 767761506.7]
}

# Convert data to DataFrame
df = pd.DataFrame(data)

# Correlation analysis
corr_matrix = df.corr()

# FDI Investment Value correlation values
fdi_investment_corr = corr_matrix['FDI Investment Value'].drop('FDI Investment Value')

# Print correlation with FDI Investment Value
print("Correlation with FDI Investment Value:")
print(fdi_investment_corr)
# Out:
# Correlation with FDI Investment Value:
# Year                                                0.365936
# Government effectiveness (Rank)                     0.386489
# Gross National Income Per Capita (2017 PPP$)        0.386489
# Individuals using the Internet (% of population)    0.386489
# Total Agent Cash in Cash Out (Volume Million)       0.386489
# Life expectancy (Years)                             0.383520
# GDP (USD)                                           0.333814
# Mean years of Schooling (Years)                     0.183878
# Labour Force Participation Rate, Female (%)        -0.354626
# Labour Force Participation Rate, Male (%)           0.183686
# HDI Index                                           0.247498
# CO2 emission per capita (tonne)                     0.158097
# Rule of law (rank)                                  0.318349
# Name: FDI Investment Value, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np  

# Set the style of the visualization
sns.set(style="white")

# Compute the correlation matrix
corr = df.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.title('Correlation Matrix of Variables')
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Create DataFrame from the provided data
data = {
    'Year': [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018],
    'Government effectiveness (Rank)': [36.89, 31.07, 30.62, 34.93, 33.65, 35.55, 37.44, 40.87, 38.57, 37.14, 37.14, 34.29],
    'Gross National Income Per Capita (2017 PPP$)': [36.89, 31.07, 30.62, 34.93, 33.65, 35.55, 37.44, 40.87, 38.57, 37.14, 37.14, 34.29],
    'Individuals using the Internet (% of population)': [36.89, 31.07, 30.62, 34.93, 33.65, 35.55, 37.44, 40.87, 38.57, 37.14, 37.14, 34.29],
    'Total Agent Cash in Cash Out (Volume Million)': [36.89, 31.07, 30.62, 34.93, 33.65, 35.55, 37.44, 40.87, 38.57, 37.14, 37.14, 34.29],
    'Life expectancy (Years)': [57.13, 58.49, 59.38, 60.26, 61.15, 62.03, 62.92, 63.57, 64.22, 64.87, 65.53, 66.18],
    'GDP (USD)': [840.19, 915.99, 1049.12, 1093.64, 1099.32, 1289.78, 1376.83, 1489.92, 1496.65, 1562.08, 1675.99, 1845.78],
    'Mean years of Schooling (Years)': [6.16, 6.23, 6.31, 5.82, 6.05, 6.3, 6.54, 6.79, 7.03, 7.27, 7.51, 7.75],
    'Labour Force Participation Rate, Female (%)': [10.8, 10.659, 10.353, 10.177, 9.734, 9.37, 9.086, 8.695, 8.143, 7.681, 7.235, 7.13],
    'Labour Force Participation Rate, Male (%)': [49.41, 48.351, 46.413, 47.55, 47.28, 47.698, 51.621, 50.685, 48.297, 50.467, 48.994, 51.151],
    'HDI Index': [0.54, 0.55, 0.55, 0.54, 0.55, 0.56, 0.56, 0.57, 0.57, 0.59, 0.59, 0.6],
    'CO2 emission per capita (tonne)': [0.258266, 0.261128, 0.305781, 0.292963, 0.315411, 0.286003, 0.300453, 0.317061, 0.362817, 0.378633, 0.361799, 0.377112],
    'Rule of law (rank)': [17.22, 16.35, 16.59, 18.01, 19.25, 23.94, 30.05, 38.94, 36.67, 35.24, 37.14, 36.67],
    'ICT exports': [328361639.2, 435638896.6, 376520262.8, 357174483, 386719989.2, 467588858.6, 515175648.6, 755711724.1, 550307434.6, 451360165.7, 473090014.3, 570245522.3]
}

df = pd.DataFrame(data)

# Compute the correlation matrix
corr = df.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.title('Correlation Matrix of Variables')
plt.show()

# Scatter plot of ICT exports with other variables
for col in df.columns:
    if col != 'ICT exports':
        plt.figure(figsize=(10, 6))
        sns.scatterplot(data=df, x='ICT exports', y=col)
        plt.title(f'Scatter Plot of ICT Exports vs. {col}')
        plt.xlabel('ICT Exports')
        plt.ylabel(col)
        plt.show()

# %%
print(corr_matrix)
# Out:
#                                                       Year  \
# Year                                              1.000000
# Government effectiveness (Rank)                   0.480025
# Gross National Income Per Capita (2017 PPP$)      0.480025
# Individuals using the Internet (% of population)  0.480025
# Total Agent Cash in Cash Out (Volume Million)     0.480025
# Life expectancy (Years)                           0.995137
# GDP (USD)                                         0.991015
# Mean years of Schooling (Years)                   0.901150
# Labour Force Participation Rate, Female (%)      -0.993050
# Labour Force Participation Rate, Male (%)         0.534439
# HDI Index                                         0.942053
# CO2 emission per capita (tonne)                   0.913812
# Rule of law (rank)                                0.923158
# FDI Investment Value                              0.365936
#
# ...

# %%
import pandas as pd
from scipy.stats import pearsonr

# Define the data
data = {
    'Year': [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018],
    'Government effectiveness (Rank)': [36.89, 31.07, 30.62, 34.93, 33.65, 35.55, 37.44, 40.87, 38.57, 37.14, 37.14, 34.29],
    'Gross National Income Per Capita (2017 PPP$)': [36.89, 31.07, 30.62, 34.93, 33.65, 35.55, 37.44, 40.87, 38.57, 37.14, 37.14, 34.29],
    'Individuals using the Internet (% of population)': [36.89, 31.07, 30.62, 34.93, 33.65, 35.55, 37.44, 40.87, 38.57, 37.14, 37.14, 34.29],
    'Total Agent Cash in Cash Out (Volume Million)': [36.89, 31.07, 30.62, 34.93, 33.65, 35.55, 37.44, 40.87, 38.57, 37.14, 37.14, 34.29],
    'Life expectancy (Years)': [57.13, 58.49, 59.38, 60.26, 61.15, 62.03, 62.92, 63.57, 64.22, 64.87, 65.53, 66.18],
    'GDP (USD)': [840.19, 915.99, 1049.12, 1093.64, 1099.32, 1289.78, 1376.83, 1489.92, 1496.65, 1562.08, 1675.99, 1845.78],
    'Mean years of Schooling (Years)': [6.16, 6.23, 6.31, 5.82, 6.05, 6.3, 6.54, 6.79, 7.03, 7.27, 7.51, 7.75],
    'Labour Force Participation Rate, Female (%)': [10.8, 10.659, 10.353, 10.177, 9.734, 9.37, 9.086, 8.695, 8.143, 7.681, 7.235, 7.13],
    'Labour Force Participation Rate, Male (%)': [49.41, 48.351, 46.413, 47.55, 47.28, 47.698, 51.621, 50.685, 48.297, 50.467, 48.994, 51.151],
    'HDI Index': [0.54, 0.55, 0.55, 0.54, 0.55, 0.56, 0.56, 0.57, 0.57, 0.59, 0.59, 0.6],
    'CO2 emission per capita (tonne)': [0.258266, 0.261128, 0.305781, 0.292963, 0.315411, 0.286003, 0.300453, 0.317061, 0.362817, 0.378633, 0.361799, 0.377112],
    'Rule of law (rank)': [17.22, 16.35, 16.59, 18.01, 19.25, 23.94, 30.05, 38.94, 36.67, 35.24, 37.14, 36.67],
    'FDI Investment Value': [328361639.2, 435638896.6, 376520262.8, 357174483, 386719989.2, 467588858.6, 515175648.6, 755711724.1, 550307434.6, 451360165.7, 473090014.3, 570245522.3]
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute correlation matrix and p-values
corr_matrix = df.corr()
p_values = df.corr(method=lambda x, y: pearsonr(x, y)[1]) - np.eye(*corr_matrix.shape)

# Display correlation matrix and p-values
print("Correlation Matrix:")
print(corr_matrix)
print("\nP-values:")
print(p_values)
# Out:
# Correlation Matrix:
#                                                       Year  \
# Year                                              1.000000
# Government effectiveness (Rank)                   0.480025
# Gross National Income Per Capita (2017 PPP$)      0.480025
# Individuals using the Internet (% of population)  0.480025
# Total Agent Cash in Cash Out (Volume Million)     0.480025
# Life expectancy (Years)                           0.995137
# GDP (USD)                                         0.991015
# Mean years of Schooling (Years)                   0.901150
# Labour Force Participation Rate, Female (%)      -0.993050
# Labour Force Participation Rate, Male (%)         0.534439
# HDI Index                                         0.942053
# CO2 emission per capita (tonne)                   0.913812
# Rule of law (rank)                                0.923158
# FDI Investment Value                              0.608858
#
# ...
